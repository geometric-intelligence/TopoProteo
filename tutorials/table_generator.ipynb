# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from utils_table_generator import *

wandb_username = "gbg141"  # Change this to your W&B username if needed
wandb_project = "Proteo"  # Change this to your W&B project name if needed
metric = "mae"  # Change this to the metric you want to extract (e.g., "mae", "mse", etc.)
original_units = True  # Set to True if you want to convert back to original units
csv_filename = "proteo_results.csv"  # Output CSV filename
save_csv = False  # Set to True if you want to save the grouped results to a CSV file

df = load_results_dataframe(wandb_username, wandb_project, original_units=original_units, metric=metric, csv_filename=csv_filename)
df, grouped, best_configs, summary, table = generate_table(df, save_csv=save_csv, csv_filename=csv_filename)
# Out:
# /home/gbg141/TopoProteo/tutorials/utils_table_generator.py:101: DtypeWarning: Columns (23,40,156,161,164,166,168,169) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_filename)
# /home/gbg141/TopoProteo/tutorials/utils_table_generator.py:206: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(ensure_hashable)
# ▶ After building df, df.shape = (5096, 170)
# ...

# %%
summary
# Out:
#                 dataset  model  mean_test_mae  std_test_mae         mean_std
# 0  spearman_correlation  GATv4       9.054851           NaN     9.0549 ± nan
# 1  spearman_correlation    gcn       6.597374      2.736523  6.5974 ± 2.7365
# 2  spearman_correlation    mlp       5.793783      1.904705  5.7938 ± 1.9047
# 3                 wgcna  GATv4       8.659469           NaN     8.6595 ± nan
# 4                 wgcna    gcn       6.379227      2.234387  6.3792 ± 2.2344
# 5                 wgcna    mlp       5.793783      1.904705  5.7938 ± 1.9047

# %%
best_configs.iloc[2]
# Out:
# dataset                                                              spearman_correlation
# model                                                                                 mlp
# dataset.dataloader_params.batch_size                                                   16
# dataset.loader.parameters.adj_thresh                                                  0.5
# model.backbone._target_                                                 torch.nn.Identity
# model.backbone.act                                                                    NaN
# model.backbone.hidden_channels                                                        NaN
# model.backbone.in_channels                                                            NaN
# model.backbone_wrapper._target_                     topobench.nn.wrappers.IdentityWrapper
# model.backbone_wrapper.out_channels                                                     1
# ...

# %%
best_configs.iloc[5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 best_configs.iloc[5]
#
# NameError: name 'best_configs' is not defined

# %%
best_configs["config_key"][5]
# Out:
# ('wgcna',
#  'mlp',
#  8,
#  0.2,
#  'torch.nn.Identity',
#  nan,
#  nan,
#  nan,
#  'topobench.nn.wrappers.IdentityWrapper',
#  1,
#  'IdentityWrapper',
#  'topobench.nn.encoders.IdentityEncoder',
#  'IdentityEncoder',
#  '1',
#  1,
#  'tanh',
#  '[1024, 1024, 512, 256]',
#  1,
#  '[512, 256]',
#  7258,
#  nan,
#  6022110,
#  6022110,
#  0.0001,
#  '[7]')

# %%
best_configs["config_key"][2]
# Out:
# ('spearman_correlation',
#  'mlp',
#  8,
#  0.6,
#  'torch.nn.Identity',
#  nan,
#  nan,
#  nan,
#  'topobench.nn.wrappers.IdentityWrapper',
#  1,
#  'IdentityWrapper',
#  'topobench.nn.encoders.IdentityEncoder',
#  'IdentityEncoder',
#  '1',
#  1,
#  'tanh',
#  '[1024, 1024, 512, 256]',
#  1,
#  '[512, 256]',
#  7258,
#  nan,
#  6022110,
#  6022110,
#  0.0001,
#  '[6]')
