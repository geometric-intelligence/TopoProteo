# %% [markdown]
# # Results table generator

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from utils_table_generator import *

wandb_username = "lcornelis"#"gbg141"#"lcornelis"  # Change this to your W&B username if needed
wandb_project = "TopoProteoGatV4"#"TopoProteoGatV4"#"ProteoBaselines"  # Change this to your W&B project name if needed
metric = "mse"  # Change this to the metric you want to extract (e.g., "mae", "mse", etc.)
original_units = True  # Set to True if you want to convert back to original units
csv_filename = wandb_project+"_"+wandb_username+"_"+"_results.csv"  # Output CSV filename
force_load = False
save_csv = False  # Set to True if you want to save the grouped results to a CSV file

df = load_results_dataframe(wandb_username, wandb_project, original_units=original_units, metric=metric, force_load=force_load, csv_filename=csv_filename)
df, grouped, best_configs, summary, table = generate_table(df, save_csv=save_csv, csv_filename=csv_filename)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ▶ After building df, df.shape = (2225, 170)
# ▶ hyperparam_cols = ['dataset.dataloader_params.batch_size', 'dataset.loader.parameters.adj_thresh', 'model.backbone.hidden_channels', 'model.backbone.in_channels', 'model.backbone_wrapper.out_channels', 'model.feature_encoder.out_channels', 'model.readout.fc_dim', 'model.readout.fc_input_dim', 'model.readout.graph_encoder_dim', 'model.readout.in_channels', 'model/params/total', 'model/params/trainable', 'optimizer.parameters.lr', 'trainer.devices']
# ▶ group_cols = ['dataset', 'model', 'dataset.dataloader_params.batch_size', 'dataset.loader.parameters.adj_thresh', 'model.backbone.hidden_channels', 'model.backbone.in_channels', 'model.backbone_wrapper.out_channels', 'model.feature_encoder.out_channels', 'model.readout.fc_dim', 'model.readout.fc_input_dim', 'model.readout.graph_encoder_dim', 'model.readout.in_channels', 'model/params/total', 'model/params/trainable', 'optimizer.parameters.lr', 'trainer.devices']
# ▶ After grouping, grouped.shape = (359, 19)
# ▶ best_configs.shape = (10, 19)
# ▶ df_best_runs.shape (should be #datasets × #models × #folds) = (50, 20)
# ▶ summary.shape = (10, 18)
# ▶ final_table.shape = (10, 18)
# | dataset              | model   |   dataset.dataloader_params.batch_size |   dataset.loader.parameters.adj_thresh | model.backbone.hidden_channels   |   model.backbone.in_channels | model.backbone_wrapper.out_channels   |   model.feature_encoder.out_channels | model.readout.fc_dim   | model.readout.fc_input_dim   |   model.readout.graph_encoder_dim | model.readout.in_channels   |   model/params/total |   model/params/trainable |   optimizer.parameters.lr | trainer.devices   |   mean_test_mae |   std_test_mae |
# |:---------------------|:--------|---------------------------------------:|---------------------------------------:|:---------------------------------|-----------------------------:|:--------------------------------------|-------------------------------------:|:-----------------------|:-----------------------------|----------------------------------:|:----------------------------|---------------------:|-------------------------:|--------------------------:|:------------------|----------------:|---------------:|
# | spearman_correlation | GATv4   |                                      1 |                                 0.6000 | [64, 128]                        |                            8 | [64, 128]                             |                                    8 | [128, 64, 32]          | [64, 128]                    |                               128 | [64, 128]                   |              3044982 |                  3044982 |                    0.0001 | [3]               |         14.2909 |         5.5971 |
# | spearman_correlation | GATv4   |                                      1 |                                 0.6000 | [64, 128]                        |                            8 | [64, 128]                             |                                    8 | [128, 64, 32]          | [64, 128]                    |                               256 | [64, 128]                   |              5848566 |                  5848566 |                    0.0001 | [3]               |         13.5252 |         4.8129 |
# | spearman_correlation | GATv4   |                                      2 |                                 0.6000 | [64, 128]                        |                            8 | [64, 128]                             |                                    8 | [128, 64, 32]          | [64, 128]                    |                               256 | [64, 128]                   |              5848566 |                  5848566 |                    0.0001 | [3]               |         12.2966 |         6.0308 |
# | spearman_correlation | GATv4   |                                      4 |                                 0.6000 | [64, 128]                        |                            8 | [64, 128]                             |                                    8 | [128, 64, 32]          | [64, 128]                    |                               128 | [64, 128]                   |              3044982 |                  3044982 |                    0.0010 | [3]               |         13.9092 |         4.5987 |
# | spearman_correlation | GATv4   |                                      4 |                                 0.6000 | [64, 128]                        |                            8 | [64, 128]                             |                                    8 | [128, 64, 32]          | [64, 128]                    |                               256 | [64, 128]                   |              5848566 |                  5848566 |                    0.0001 | [3]               |         14.4933 |         5.7123 |
# | wgcna                | GATv4   |                                      1 |                                 0.2000 | [64, 128]                        |                            8 | [64, 128]                             |                                    8 | [128, 64, 32]          | [64, 128]                    |                               128 | [64, 128]                   |              3044982 |                  3044982 |                    0.0001 | [7]               |         13.4324 |         6.8478 |
# | wgcna                | GATv4   |                                      1 |                                 0.2000 | [8, 16]                          |                            8 | [8, 16]                               |                                    8 | [128, 64, 32]          | [8, 16]                      |                               128 | [8, 16]                     |              2878494 |                  2878494 |                    0.0001 | [6]               |         13.7639 |         5.0350 |
# | wgcna                | GATv4   |                                      1 |                                 0.2500 | [64, 128]                        |                            8 | [64, 128]                             |                                    8 | [128, 64, 32]          | [64, 128]                    |                               128 | [64, 128]                   |              3044982 |                  3044982 |                    0.0001 | [7]               |         12.3162 |         4.7796 |
# | wgcna                | GATv4   |                                      2 |                                 0.2000 | [64, 128]                        |                            8 | [64, 128]                             |                                    8 | [128, 64, 32]          | [64, 128]                    |                               128 | [64, 128]                   |              3044982 |                  3044982 |                    0.0001 | [7]               |         11.9984 |         5.9324 |
# | wgcna                | GATv4   |                                      4 |                                 0.2500 | [64, 128]                        |                            8 | [64, 128]                             |                                    8 | [128, 64, 32]          | [64, 128]                    |                               128 | [64, 128]                   |              3044982 |                  3044982 |                    0.0001 | [7]               |         12.7738 |         6.5206 |
# | ('dataset', '')      | ('GATv4', 1)     | ('GATv4', 2)     | ('GATv4', 3)     | ('GATv4', 4)     | ('GATv4', 5)     |
# |:---------------------|:-----------------|:-----------------|:-----------------|:-----------------|:-----------------|
# | spearman_correlation | 12.2966 ± 6.0308 | 13.5252 ± 4.8129 | 13.9092 ± 4.5987 | 14.2909 ± 5.5971 | 14.4933 ± 5.7123 |
# | wgcna                | 11.9984 ± 5.9324 | 12.3162 ± 4.7796 | 12.7738 ± 6.5206 | 13.4324 ± 6.8478 | 13.7639 ± 5.0350 |

# %%
summary
# Out:
#                 dataset  model  dataset.dataloader_params.batch_size  \
# 0  spearman_correlation  GATv4                                     1
# 1  spearman_correlation  GATv4                                     1
# 2  spearman_correlation  GATv4                                     2
# 3  spearman_correlation  GATv4                                     4
# 4  spearman_correlation  GATv4                                     4
# 5                 wgcna  GATv4                                     1
# 6                 wgcna  GATv4                                     1
# 7                 wgcna  GATv4                                     1
# 8                 wgcna  GATv4                                     2
# 9                 wgcna  GATv4                                     4
#
#    dataset.loader.parameters.adj_thresh model.backbone.hidden_channels  \
# 0                                  0.60                      [64, 128]
# 1                                  0.60                      [64, 128]
# 2                                  0.60                      [64, 128]
# 3                                  0.60                      [64, 128]
# 4                                  0.60                      [64, 128]
# 5                                  0.20                      [64, 128]
# 6                                  0.20                        [8, 16]
# 7                                  0.25                      [64, 128]
# 8                                  0.20                      [64, 128]
# 9                                  0.25                      [64, 128]
#
#    model.backbone.in_channels model.backbone_wrapper.out_channels  \
# 0                           8                           [64, 128]
# 1                           8                           [64, 128]
# 2                           8                           [64, 128]
# 3                           8                           [64, 128]
# 4                           8                           [64, 128]
# 5                           8                           [64, 128]
# 6                           8                             [8, 16]
# 7                           8                           [64, 128]
# 8                           8                           [64, 128]
# 9                           8                           [64, 128]
#
#    model.feature_encoder.out_channels model.readout.fc_dim  \
# 0                                   8        [128, 64, 32]
# 1                                   8        [128, 64, 32]
# 2                                   8        [128, 64, 32]
# 3                                   8        [128, 64, 32]
# 4                                   8        [128, 64, 32]
# 5                                   8        [128, 64, 32]
# 6                                   8        [128, 64, 32]
# 7                                   8        [128, 64, 32]
# 8                                   8        [128, 64, 32]
# 9                                   8        [128, 64, 32]
#
#   model.readout.fc_input_dim  model.readout.graph_encoder_dim  \
# 0                  [64, 128]                              128
# 1                  [64, 128]                              256
# 2                  [64, 128]                              256
# 3                  [64, 128]                              128
# 4                  [64, 128]                              256
# 5                  [64, 128]                              128
# 6                    [8, 16]                              128
# 7                  [64, 128]                              128
# 8                  [64, 128]                              128
# 9                  [64, 128]                              128
#
#   model.readout.in_channels  model/params/total  model/params/trainable  \
# 0                 [64, 128]             3044982                 3044982
# 1                 [64, 128]             5848566                 5848566
# 2                 [64, 128]             5848566                 5848566
# 3                 [64, 128]             3044982                 3044982
# 4                 [64, 128]             5848566                 5848566
# 5                 [64, 128]             3044982                 3044982
# 6                   [8, 16]             2878494                 2878494
# 7                 [64, 128]             3044982                 3044982
# 8                 [64, 128]             3044982                 3044982
# 9                 [64, 128]             3044982                 3044982
#
#    optimizer.parameters.lr trainer.devices  mean_test_mae  std_test_mae  \
# 0                   0.0001             [3]      14.290916      5.597110
# 1                   0.0001             [3]      13.525155      4.812872
# 2                   0.0001             [3]      12.296561      6.030771
# 3                   0.0010             [3]      13.909165      4.598721
# 4                   0.0001             [3]      14.493326      5.712267
# 5                   0.0001             [7]      13.432430      6.847849
# 6                   0.0001             [6]      13.763861      5.034964
# 7                   0.0001             [7]      12.316161      4.779589
# 8                   0.0001             [7]      11.998368      5.932412
# 9                   0.0001             [7]      12.773824      6.520562
#
#            mean_std  rank
# 0  14.2909 ± 5.5971     4
# 1  13.5252 ± 4.8129     2
# 2  12.2966 ± 6.0308     1
# 3  13.9092 ± 4.5987     3
# 4  14.4933 ± 5.7123     5
# 5  13.4324 ± 6.8478     4
# 6  13.7639 ± 5.0350     5
# 7  12.3162 ± 4.7796     2
# 8  11.9984 ± 5.9324     1
# 9  12.7738 ± 6.5206     3

# %%
best_configs.iloc[1]
# Out:
# dataset                                                                             wgcna
# model                                                                               GATv4
# dataset.dataloader_params.batch_size                                                    2
# dataset.loader.parameters.adj_thresh                                                  0.2
# model.backbone.hidden_channels                                                  [64, 128]
# model.backbone.in_channels                                                              8
# model.backbone_wrapper.out_channels                                             [64, 128]
# model.feature_encoder.out_channels                                                      8
# model.readout.fc_dim                                                        [128, 64, 32]
# model.readout.fc_input_dim                                                      [64, 128]
# model.readout.graph_encoder_dim                                                       128
# model.readout.in_channels                                                       [64, 128]
# model/params/total                                                                3044982
# model/params/trainable                                                            3044982
# optimizer.parameters.lr                                                            0.0001
# trainer.devices                                                                       [7]
# mean_val_mae                                                                    11.998368
# std_val_mae                                                                      5.932412
# n_folds                                                                                 5
# config_key                              (wgcna, GATv4, 2, 0.2, [64, 128], 8, [64, 128]...
# Name: 1, dtype: object

# %%
best_configs.iloc[5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 best_configs.iloc[5]
#
# NameError: name 'best_configs' is not defined

# %%
best_configs["config_key"][5]
# Out:
# ('wgcna',
#  'mlp',
#  8,
#  0.2,
#  'torch.nn.Identity',
#  nan,
#  nan,
#  nan,
#  'topobench.nn.wrappers.IdentityWrapper',
#  1,
#  'IdentityWrapper',
#  'topobench.nn.encoders.IdentityEncoder',
#  'IdentityEncoder',
#  '1',
#  1,
#  'tanh',
#  '[1024, 1024, 512, 256]',
#  1,
#  '[512, 256]',
#  7258,
#  nan,
#  6022110,
#  6022110,
#  0.0001,
#  '[7]')

# %%
best_configs["config_key"][2]
# Out:
# ('spearman_correlation',
#  'mlp',
#  8,
#  0.6,
#  'torch.nn.Identity',
#  nan,
#  nan,
#  nan,
#  'topobench.nn.wrappers.IdentityWrapper',
#  1,
#  'IdentityWrapper',
#  'topobench.nn.encoders.IdentityEncoder',
#  'IdentityEncoder',
#  '1',
#  1,
#  'tanh',
#  '[1024, 1024, 512, 256]',
#  1,
#  '[512, 256]',
#  7258,
#  nan,
#  6022110,
#  6022110,
#  0.0001,
#  '[6]')
