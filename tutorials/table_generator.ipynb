# %% [markdown]
# # Results table generator

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from utils_table_generator import *

wandb_username = "gbg141"#"gbg141"#"lcornelis"  # Change this to your W&B username if needed
wandb_project = "Proteo_small" #"TopoProteoGatV4"#"ProteoBaselines"  # Change this to your W&B project name if needed
metric = "mse"  # Change this to the metric you want to extract (e.g., "mae", "mse", etc.)
original_units = True  # Set to True if you want to convert back to original units
csv_filename = wandb_project+"_"+wandb_username+"_"+"_results.csv"  # Output CSV filename
force_load = False
save_csv = False  # Set to True if you want to save the grouped results to a CSV file

df = load_results_dataframe(wandb_username, wandb_project, original_units=original_units, metric=metric, force_load=force_load, csv_filename=csv_filename)
df, grouped, best_configs, summary, table = generate_table(df, save_csv=save_csv, csv_filename=csv_filename)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ▶ Number of runs fetched from W&B: 2641
# ▶ After building df, df.shape = (2630, 174)
# ▶ hyperparam_cols = ['dataset.dataloader_params.batch_size', 'dataset.loader.parameters.adj_thresh', 'model.backbone._target_', 'model.backbone.act', 'model.backbone.dropout', 'model.backbone.heads', 'model.backbone.hidden_channels', 'model.backbone_wrapper._target_', 'model.backbone_wrapper.out_channels', 'model.backbone_wrapper.wrapper_name', 'model.feature_encoder._target_', 'model.feature_encoder.encoder_name', 'model.feature_encoder.in_channels', 'model.feature_encoder.out_channels', 'model.readout.fc_act', 'model.readout.fc_dim', 'model.readout.fc_dropout', 'model.readout.fc_input_dim', 'model.readout.feature_encoder_dim', 'model.readout.graph_encoder_dim', 'model.readout.hidden_dim', 'model.readout.in_channels', 'model.readout.use_features', 'model/params/total', 'model/params/trainable', 'optimizer.parameters.lr', 'trainer.devices']
# ▶ group_cols = ['dataset', 'model', 'dataset.dataloader_params.batch_size', 'dataset.loader.parameters.adj_thresh', 'model.backbone._target_', 'model.backbone.act', 'model.backbone.dropout', 'model.backbone.heads', 'model.backbone.hidden_channels', 'model.backbone_wrapper._target_', 'model.backbone_wrapper.out_channels', 'model.backbone_wrapper.wrapper_name', 'model.feature_encoder._target_', 'model.feature_encoder.encoder_name', 'model.feature_encoder.in_channels', 'model.feature_encoder.out_channels', 'model.readout.fc_act', 'model.readout.fc_dim', 'model.readout.fc_dropout', 'model.readout.fc_input_dim', 'model.readout.feature_encoder_dim', 'model.readout.graph_encoder_dim', 'model.readout.hidden_dim', 'model.readout.in_channels', 'model.readout.use_features', 'model/params/total', 'model/params/trainable', 'optimizer.parameters.lr', 'trainer.devices']
# ▶ After grouping, grouped.shape = (622, 32)
# ▶ best_configs.shape = (4, 32)
# ▶ df_best_runs.shape (should be #datasets × #models × #folds) = (11, 33)
# ▶ summary.shape = (4, 4)
# ▶ final_table.shape = (4, 31)
# | dataset    | model   |   dataset.dataloader_params.batch_size |   dataset.loader.parameters.adj_thresh | model.backbone._target_       | model.backbone.act   |   model.backbone.dropout | model.backbone.heads   | model.backbone.hidden_channels   | model.backbone_wrapper._target_       | model.backbone_wrapper.out_channels   | model.backbone_wrapper.wrapper_name   | model.feature_encoder._target_              | model.feature_encoder.encoder_name   | model.feature_encoder.in_channels   |   model.feature_encoder.out_channels | model.readout.fc_act   | model.readout.fc_dim   |   model.readout.fc_dropout | model.readout.fc_input_dim   |   model.readout.feature_encoder_dim | model.readout.graph_encoder_dim   |   model.readout.hidden_dim | model.readout.in_channels   |   model.readout.use_features |   model/params/total |   model/params/trainable |   optimizer.parameters.lr | trainer.devices   |   mean_test_mae |   std_test_mae |
# |:-----------|:--------|---------------------------------------:|---------------------------------------:|:------------------------------|:---------------------|-------------------------:|:-----------------------|:---------------------------------|:--------------------------------------|:--------------------------------------|:--------------------------------------|:--------------------------------------------|:-------------------------------------|:------------------------------------|-------------------------------------:|:-----------------------|:-----------------------|---------------------------:|:-----------------------------|------------------------------------:|:----------------------------------|---------------------------:|:----------------------------|-----------------------------:|---------------------:|-------------------------:|--------------------------:|:------------------|----------------:|---------------:|
# | pointcloud | mlp     |                                     32 |                                 1.0000 | torch.nn.Identity             | nan                  |                 nan      | nan                    | nan                              | topobench.nn.wrappers.IdentityWrapper | 1                                     | IdentityWrapper                       | topobench.nn.encoders.IdentityEncoder       | IdentityEncoder                      | 1                                   |                                    1 | tanh                   | (128, 32, 16)          |                     0.1000 | 1                            |                                   8 | (32, 16)                          |                       7258 | nan                         |                       1.0000 |               250078 |                   250078 |                    0.0010 | (4,)              |         11.9393 |         4.9955 |
# | wgcna      | GATv4   |                                      8 |                                 0.3000 | topobench.nn.backbones.GATv4  | relu                 |                   0.2000 | (3, 3)                 | (16, 32)                         | topobench.nn.wrappers.GATv4Wrapper    | (16, 32)                              | GATv4Wrapper                          | topobench.nn.encoders.AllCellFeatureEncoder | AllCellFeatureEncoder                | (1,)                                |                                    2 | relu                   | (8, 4, 2)              |                     0.2000 | (16, 32)                     |                                   8 | 32                                |                      21774 | (16, 32)                    |                       0.0000 |               744574 |                   744574 |                    0.0010 | (5,)              |         14.7039 |         3.6308 |
# | wgcna      | gat     |                                      8 |                                 0.2000 | torch_geometric.nn.models.GAT | tanh                 |                   0.1000 | 2                      | 2                                | topobench.nn.wrappers.GNNWrapper      | 2                                     | GNNWrapper                            | topobench.nn.encoders.AllCellFeatureEncoder | AllCellFeatureEncoder                | (1,)                                |                                    2 | relu                   | (16, 8, 4)             |                     0.2500 | 2                            |                                   4 | 16                                |                      14516 | 2                           |                     nan      |               247490 |                   247490 |                    0.0010 | (1,)              |         17.5589 |         0.3325 |
# | wgcna      | gcn     |                                      8 |                                 0.2000 | torch_geometric.nn.models.GCN | tanh                 |                   0.1000 | nan                    | 2                                | topobench.nn.wrappers.GNNWrapper      | 2                                     | GNNWrapper                            | topobench.nn.encoders.AllCellFeatureEncoder | AllCellFeatureEncoder                | (1,)                                |                                    2 | relu                   | (16, 8, 4)             |                     0.2500 | 2                            |                                   4 | 16                                |                      14516 | 2                           |                     nan      |               247470 |                   247470 |                    0.0010 | (3,)              |         16.0769 |         1.6351 |
# | ('dataset', '')   | ('GATv4', 1)     | ('gat', 1)       | ('gcn', 1)       | ('mlp', 1)       |
# |:------------------|:-----------------|:-----------------|:-----------------|:-----------------|
# | pointcloud        | nan              | nan              | nan              | 11.9393 ± 4.9955 |
# | wgcna             | 14.7039 ± 3.6308 | 17.5589 ± 0.3325 | 16.0769 ± 1.6351 | nan              |

# %%
best_configs
# Out:
#         dataset  model  dataset.dataloader_params.batch_size  \
# 27   pointcloud    mlp                                    16
# 73        wgcna  GATv4                                     8
# 105       wgcna    gat                                    16
# 148       wgcna    gcn                                    16
#
#      dataset.loader.parameters.adj_thresh        model.backbone._target_  \
# 27                                    1.0              torch.nn.Identity
# 73                                    0.5   topobench.nn.backbones.GATv4
# 105                                   0.5  torch_geometric.nn.models.GAT
# 148                                   0.5  torch_geometric.nn.models.GCN
#
#      model.backbone.dropout model.backbone.heads  \
# 27                      NaN                  NaN
# 73                      0.2               [3, 3]
# 105                     0.3                    4
# 148                     0.1                  NaN
#
#     model.backbone.hidden_channels        model.backbone_wrapper._target_  \
# 27                             NaN  topobench.nn.wrappers.IdentityWrapper
# 73                         [8, 16]     topobench.nn.wrappers.GATv4Wrapper
# 105                              4       topobench.nn.wrappers.GNNWrapper
# 148                              4       topobench.nn.wrappers.GNNWrapper
#
#     model.backbone_wrapper.out_channels  ... model.readout.hidden_dim  \
# 27                                    1  ...                     7258
# 73                              [8, 16]  ...                    21774
# 105                                   4  ...                    29032
# 148                                   4  ...                    29032
#
#     model.readout.in_channels model.readout.use_features model/params/total  \
# 27                        NaN                       True             478270
# 73                    [8, 16]                      False             736950
# 105                         4                        NaN             959338
# 148                         4                        NaN             494298
#
#      model/params/trainable trainer.devices  mean_val_mae std_val_mae  \
# 27                   478270             [4]     11.524809    3.185176
# 73                   736950             [7]     17.282399    2.777515
# 105                  959338             [0]     16.021246    2.537273
# 148                  494298             [3]     15.813309    2.615189
#
#      n_folds                                         config_key
# 27         5  (pointcloud, mlp, 16, 1.0, torch.nn.Identity, ...
# 73         4  (wgcna, GATv4, 8, 0.5, topobench.nn.backbones....
# 105        5  (wgcna, gat, 16, 0.5, torch_geometric.nn.model...
# 148        5  (wgcna, gcn, 16, 0.5, torch_geometric.nn.model...
#
# [4 rows x 30 columns]

# %%
grouped
# Out:
#         dataset  model  dataset.dataloader_params.batch_size  \
# 0    pointcloud    mlp                                     8
# 1    pointcloud    mlp                                     8
# 2    pointcloud    mlp                                     8
# 3    pointcloud    mlp                                     8
# 4    pointcloud    mlp                                     8
# ..          ...    ...                                   ...
# 441       wgcna  GATv4                                     8
# 442       wgcna  GATv4                                     8
# 443       wgcna  GATv4                                     8
# 444       wgcna  GATv4                                     8
# 445       wgcna  GATv4                                     8
#
#      dataset.loader.parameters.adj_thresh       model.backbone._target_  \
# 0                                    1.00             torch.nn.Identity
# 1                                    1.00             torch.nn.Identity
# 2                                    1.00             torch.nn.Identity
# 3                                    1.00             torch.nn.Identity
# 4                                    1.00             torch.nn.Identity
# ..                                    ...                           ...
# 441                                  0.25  topobench.nn.backbones.GATv4
# 442                                  0.25  topobench.nn.backbones.GATv4
# 443                                  0.25  topobench.nn.backbones.GATv4
# 444                                  0.30  topobench.nn.backbones.GATv4
# 445                                  0.30  topobench.nn.backbones.GATv4
#
#     model.backbone.act  model.backbone.dropout model.backbone.heads  \
# 0                  NaN                     NaN                  NaN
# 1                  NaN                     NaN                  NaN
# 2                  NaN                     NaN                  NaN
# 3                  NaN                     NaN                  NaN
# 4                  NaN                     NaN                  NaN
# ..                 ...                     ...                  ...
# 441               relu                     0.4               [3, 3]
# 442               relu                     0.4               [3, 3]
# 443               relu                     0.4               [3, 3]
# 444               relu                     0.4               [3, 3]
# 445               relu                     0.4               [3, 3]
#
#     model.backbone.hidden_channels        model.backbone_wrapper._target_  \
# 0                              NaN  topobench.nn.wrappers.IdentityWrapper
# 1                              NaN  topobench.nn.wrappers.IdentityWrapper
# 2                              NaN  topobench.nn.wrappers.IdentityWrapper
# 3                              NaN  topobench.nn.wrappers.IdentityWrapper
# 4                              NaN  topobench.nn.wrappers.IdentityWrapper
# ..                             ...                                    ...
# 441                       [16, 32]     topobench.nn.wrappers.GATv4Wrapper
# 442                        [8, 16]     topobench.nn.wrappers.GATv4Wrapper
# 443                        [8, 16]     topobench.nn.wrappers.GATv4Wrapper
# 444                       [16, 32]     topobench.nn.wrappers.GATv4Wrapper
# 445                        [8, 16]     topobench.nn.wrappers.GATv4Wrapper
#
#      ... model.readout.hidden_dim model.readout.in_channels  \
# 0    ...                     7258                       NaN
# 1    ...                     7258                       NaN
# 2    ...                     7258                       NaN
# 3    ...                     7258                       NaN
# 4    ...                     7258                       NaN
# ..   ...                      ...                       ...
# 441  ...                    21774                  [16, 32]
# 442  ...                    21774                   [8, 16]
# 443  ...                    21774                   [8, 16]
# 444  ...                    21774                  [16, 32]
# 445  ...                    21774                   [8, 16]
#
#     model.readout.use_features model/params/total model/params/trainable  \
# 0                         True             248534                 248534
# 1                         True             248534                 248534
# 2                         True             484486                 484486
# 3                         True             484486                 484486
# 4                         True             250078                 250078
# ..                         ...                ...                    ...
# 441                      False             744574                 744574
# 442                      False             387910                 387910
# 443                      False             736438                 736438
# 444                      False             744574                 744574
# 445                      False             736438                 736438
#
#      optimizer.parameters.lr trainer.devices mean_val_mae  std_val_mae n_folds
# 0                     0.0001             [4]    13.464873     3.711611       5
# 1                     0.0010             [4]    14.361258     2.852578       5
# 2                     0.0001             [4]    14.009069     3.502408       5
# 3                     0.0010             [4]    14.775785     4.044234       5
# 4                     0.0001             [4]    13.042666     3.754864       5
# ..                       ...             ...          ...          ...     ...
# 441                   0.0010             [7]    15.534735     4.831122       5
# 442                   0.0010             [6]    17.038696     4.204840       5
# 443                   0.0010             [7]    20.335993     2.029063       5
# 444                   0.0010             [7]    17.755489     3.967473       4
# 445                   0.0010             [7]    19.679412     1.384224       4
#
# [446 rows x 32 columns]

# %%
best_configs.iloc[1]
# Out:
# dataset                                                                             wgcna
# model                                                                               GATv4
# dataset.dataloader_params.batch_size                                                    2
# dataset.loader.parameters.adj_thresh                                                  0.2
# model.backbone.hidden_channels                                                  [64, 128]
# model.backbone.in_channels                                                              8
# model.backbone_wrapper.out_channels                                             [64, 128]
# model.feature_encoder.out_channels                                                      8
# model.readout.fc_dim                                                        [128, 64, 32]
# model.readout.fc_input_dim                                                      [64, 128]
# model.readout.graph_encoder_dim                                                       128
# model.readout.in_channels                                                       [64, 128]
# model/params/total                                                                3044982
# model/params/trainable                                                            3044982
# optimizer.parameters.lr                                                            0.0001
# trainer.devices                                                                       [7]
# mean_val_mae                                                                    11.998368
# std_val_mae                                                                      5.932412
# n_folds                                                                                 5
# config_key                              (wgcna, GATv4, 2, 0.2, [64, 128], 8, [64, 128]...
# Name: 1, dtype: object

# %%
best_configs
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 best_configs.iloc[5]
#
# File ~/miniconda3/envs/proteo/lib/python3.11/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/miniconda3/envs/proteo/lib/python3.11/site-packages/pandas/core/indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#    1754 return self.obj._ixs(key, axis=axis)
#
# File ~/miniconda3/envs/proteo/lib/python3.11/site-packages/pandas/core/indexing.py:1685, in _iLocIndexer._validate_integer(self, key, axis)
#    1683 len_axis = len(self.obj._get_axis(axis))
#    1684 if key >= len_axis or key < -len_axis:
# -> 1685     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
best_configs["config_key"][5]
# Out:
# ('wgcna',
#  'mlp',
#  8,
#  0.2,
#  'torch.nn.Identity',
#  nan,
#  nan,
#  nan,
#  'topobench.nn.wrappers.IdentityWrapper',
#  1,
#  'IdentityWrapper',
#  'topobench.nn.encoders.IdentityEncoder',
#  'IdentityEncoder',
#  '1',
#  1,
#  'tanh',
#  '[1024, 1024, 512, 256]',
#  1,
#  '[512, 256]',
#  7258,
#  nan,
#  6022110,
#  6022110,
#  0.0001,
#  '[7]')

# %%
best_configs["config_key"][2]
# Out:
# ('spearman_correlation',
#  'mlp',
#  8,
#  0.6,
#  'torch.nn.Identity',
#  nan,
#  nan,
#  nan,
#  'topobench.nn.wrappers.IdentityWrapper',
#  1,
#  'IdentityWrapper',
#  'topobench.nn.encoders.IdentityEncoder',
#  'IdentityEncoder',
#  '1',
#  1,
#  'tanh',
#  '[1024, 1024, 512, 256]',
#  1,
#  '[512, 256]',
#  7258,
#  nan,
#  6022110,
#  6022110,
#  0.0001,
#  '[6]')
