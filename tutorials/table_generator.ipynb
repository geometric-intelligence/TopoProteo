# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from utils_table_generator import *

wandb_username = "lcornelis"#"gbg141"  # Change this to your W&B username if needed
wandb_project = "TopoProteoGatV4"#"Proteo"  # Change this to your W&B project name if needed
metric = "mse"  # Change this to the metric you want to extract (e.g., "mae", "mse", etc.)
original_units = True  # Set to True if you want to convert back to original units
csv_filename = "proteogatv4_results.csv"  # Output CSV filename
save_csv = False  # Set to True if you want to save the grouped results to a CSV file

df = load_results_dataframe(wandb_username, wandb_project, original_units=original_units, metric=metric, csv_filename=csv_filename)
df, grouped, best_configs, summary, table = generate_table(df, save_csv=save_csv, csv_filename=csv_filename)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ▶ After building df, df.shape = (707, 169)
# ▶ hyperparam_cols = ['dataset.dataloader_params.batch_size', 'dataset.loader.parameters.adj_thresh', 'model.backbone.hidden_channels', 'model.backbone.in_channels', 'model.backbone_wrapper.out_channels', 'model.feature_encoder.out_channels', 'model.readout.fc_dim', 'model.readout.fc_input_dim', 'model.readout.graph_encoder_dim', 'model.readout.in_channels', 'model/params/total', 'model/params/trainable', 'optimizer.parameters.lr', 'trainer.devices']
# ▶ group_cols = ['dataset', 'model', 'dataset.dataloader_params.batch_size', 'dataset.loader.parameters.adj_thresh', 'model.backbone.hidden_channels', 'model.backbone.in_channels', 'model.backbone_wrapper.out_channels', 'model.feature_encoder.out_channels', 'model.readout.fc_dim', 'model.readout.fc_input_dim', 'model.readout.graph_encoder_dim', 'model.readout.in_channels', 'model/params/total', 'model/params/trainable', 'optimizer.parameters.lr', 'trainer.devices']
# ▶ After grouping, grouped.shape = (218, 19)
# ▶ best_configs.shape = (2, 19)
# ▶ df_best_runs.shape (should be #datasets × #models × #folds) = (6, 20)
# ▶ summary.shape = (2, 4)
# ▶ final_table.shape = (2, 18)
# | dataset              | model   |   dataset.dataloader_params.batch_size |   dataset.loader.parameters.adj_thresh | model.backbone.hidden_channels   |   model.backbone.in_channels | model.backbone_wrapper.out_channels   |   model.feature_encoder.out_channels | model.readout.fc_dim   | model.readout.fc_input_dim   |   model.readout.graph_encoder_dim | model.readout.in_channels   |   model/params/total |   model/params/trainable |   optimizer.parameters.lr | trainer.devices   |   mean_test_mae |   std_test_mae |
# |:---------------------|:--------|---------------------------------------:|---------------------------------------:|:---------------------------------|-----------------------------:|:--------------------------------------|-------------------------------------:|:-----------------------|:-----------------------------|----------------------------------:|:----------------------------|---------------------:|-------------------------:|--------------------------:|:------------------|----------------:|---------------:|
# | spearman_correlation | GATv4   |                                      2 |                                 0.6000 | [64, 128]                        |                            8 | [64, 128]                             |                                    8 | [128, 64, 32]          | [64, 128]                    |                               256 | [64, 128]                   |              5848566 |                  5848566 |                    0.0001 | [3]               |         15.3633 |         5.4979 |
# | wgcna                | GATv4   |                                      2 |                                 0.2000 | [64, 128]                        |                            8 | [64, 128]                             |                                    8 | [128, 64, 32]          | [64, 128]                    |                               128 | [64, 128]                   |              3044982 |                  3044982 |                    0.0001 | [7]               |         14.5021 |         6.8169 |
#
# === Test‐mae (mean ± std) with models as rows, datasets as columns ===
#
# | dataset              | GATv4            |
# |:---------------------|:-----------------|
# | spearman_correlation | 15.3633 ± 5.4979 |
# | wgcna                | 14.5021 ± 6.8169 |
# /home/gbg141/TopoProteo/tutorials/utils_table_generator.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(ensure_hashable)
# /home/gbg141/TopoProteo/tutorials/utils_table_generator.py:268: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["config_key"]          = df.apply(lambda r: make_config_key(r, grouped_cols), axis=1)

# %%
summary
# Out:
#                 dataset  model  mean_test_mae  std_test_mae          mean_std
# 0  spearman_correlation  GATv4      15.363340      5.497859  15.3633 ± 5.4979
# 1                 wgcna  GATv4      14.502081      6.816899  14.5021 ± 6.8169

# %%
best_configs.iloc[2]
# Out:
# dataset                                                              spearman_correlation
# model                                                                                 mlp
# dataset.dataloader_params.batch_size                                                   16
# dataset.loader.parameters.adj_thresh                                                  0.5
# model.backbone._target_                                                 torch.nn.Identity
# model.backbone.act                                                                    NaN
# model.backbone.hidden_channels                                                        NaN
# model.backbone.in_channels                                                            NaN
# model.backbone_wrapper._target_                     topobench.nn.wrappers.IdentityWrapper
# model.backbone_wrapper.out_channels                                                     1
# model.backbone_wrapper.wrapper_name                                       IdentityWrapper
# model.feature_encoder._target_                      topobench.nn.encoders.IdentityEncoder
# model.feature_encoder.encoder_name                                        IdentityEncoder
# model.feature_encoder.in_channels                                                       1
# model.feature_encoder.out_channels                                                      1
# model.readout.fc_act                                                                 tanh
# model.readout.fc_dim                                                        [128, 64, 32]
# model.readout.fc_input_dim                                                              1
# model.readout.graph_encoder_dim                                                [512, 256]
# model.readout.hidden_dim                                                             7258
# model.readout.in_channels                                                             NaN
# model/params/total                                                                3924190
# model/params/trainable                                                            3924190
# optimizer.parameters.lr                                                             0.001
# trainer.devices                                                                       [6]
# mean_val_mae                                                                     5.793783
# std_val_mae                                                                      1.904705
# n_folds                                                                                 5
# config_key                              (spearman_correlation, mlp, 16, 0.5, torch.nn....
# Name: 2, dtype: object

# %%
best_configs.iloc[5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 best_configs.iloc[5]
#
# NameError: name 'best_configs' is not defined

# %%
best_configs["config_key"][5]
# Out:
# ('wgcna',
#  'mlp',
#  8,
#  0.2,
#  'torch.nn.Identity',
#  nan,
#  nan,
#  nan,
#  'topobench.nn.wrappers.IdentityWrapper',
#  1,
#  'IdentityWrapper',
#  'topobench.nn.encoders.IdentityEncoder',
#  'IdentityEncoder',
#  '1',
#  1,
#  'tanh',
#  '[1024, 1024, 512, 256]',
#  1,
#  '[512, 256]',
#  7258,
#  nan,
#  6022110,
#  6022110,
#  0.0001,
#  '[7]')

# %%
best_configs["config_key"][2]
# Out:
# ('spearman_correlation',
#  'mlp',
#  8,
#  0.6,
#  'torch.nn.Identity',
#  nan,
#  nan,
#  nan,
#  'topobench.nn.wrappers.IdentityWrapper',
#  1,
#  'IdentityWrapper',
#  'topobench.nn.encoders.IdentityEncoder',
#  'IdentityEncoder',
#  '1',
#  1,
#  'tanh',
#  '[1024, 1024, 512, 256]',
#  1,
#  '[512, 256]',
#  7258,
#  nan,
#  6022110,
#  6022110,
#  0.0001,
#  '[6]')
